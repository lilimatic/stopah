# %%
import pandas as pd
import missingno as msno

# %%
df = pd.read_csv('/home/jlm217/rds/rds-mrc-bsu-csoP2nj6Y6Y/mimah/stopah/stopah/data/stopah.csv')

# %%
variables = ['Bilirubin.Merged',
'Creatinine...Merged',
'NLR_0',
'bDNA',
'Ferritin_ngml']

# %%
example = df[variables]

# %%
example.columns = ['Bilirubin','Creatinine','Neutrophil/Lymphocyte','Circulating bacterial DNA','Ferritin ']

# %%
## Missing data situation

# %matplotlib inline
msno.bar(example)
fig = msno.bar(example)
fig_copy = fig.get_figure()
