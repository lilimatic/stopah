# %% [markdown]
# ## Data overview

# %%
import numpy as np
import pandas as pd 
import os 

import missingno as msno

import matplotlib.pyplot as plt

#!/usr/local/Cluster-Apps/python/3.11.0-icl/bin/python3.11 -m pip install missingno

# %%
os.chdir('/home/jlm217/rds/rds-mrc-bsu-csoP2nj6Y6Y/mimah/stopah/stopah/data') 

#os.getcwd()

# %%
df = pd.read_csv('data_clinical.tsv',sep='\t')

#Data cleansing 

df.columns = df.columns.str.removesuffix('\\')

df.columns = df.columns.str.removeprefix('\\Private Studies\\STOPAH1\\')

# %%
# %matplotlib inline
msno.bar(df)

fig = msno.bar(df)
fig_copy = fig.get_figure()
fig_copy.savefig('/home/jlm217/rds/rds-mrc-bsu-csoP2nj6Y6Y/mimah/stopah/lili/missing data.png')
